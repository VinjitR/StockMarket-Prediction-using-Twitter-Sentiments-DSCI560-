# %%
import tweepy
import time
import pandas as pd

# %%
from tweepy import OAuthHandler
from tweepy import API

# %% [markdown]
# # method 3

# %%
APIKey="UzI9I5biClD5o0UhLPZc9RyTG"
APIKeySecret="Op6aasbLRJK81xyVAHE8UNQnf0CNsuMDj8EiIGx8IdH1klCAOV"
access_token="1493702658103799808-GSllRNLoSJmXrjMSjxWJYI5ajZsgMy"
access_token_secret="clWEsifZQRF7Ep71nEPNrQZfK1w99Wv0DgirPWq9OZR4m"

# %%
auth = tweepy.OAuthHandler(APIKey, APIKeySecret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
MSFT_tweets = tweepy.Cursor(api.search,
                       q="#TSLA",
                       lang="en",
                       since="2019-01-01",count=1000).items()
print(MSFT_tweets)
MSFT_tweets_list = [[tweet.created_at, tweet.id, tweet.text,tweet.user.name] for tweet in MSFT_tweets]
print(len(MSFT_tweets_list))
# q="$GOOGL", since="2022-2-14", 
tweets_dataf = pd.DataFrame(MSFT_tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
# Display first 5 entries from dataframe
tweets_dataf.head()
# Out:
# ...
# 3871
#              Datetime  ...                 Username
# 0 2022-03-02 22:19:59  ...  Pambansa Unang Darating
# 1 2022-03-02 22:12:17  ...            Monty B. VIII
# 2 2022-03-02 22:07:33  ...                Azor_Ahai
# 3 2022-03-02 22:06:35  ...                 Motive81
# 4 2022-03-02 22:06:04  ...                the HI GI
#
# [5 rows x 4 columns]

# %%
tweets_dataf
# Out:
#                 Datetime  ...                        Username
# 0    2022-03-02 22:19:59  ...         Pambansa Unang Darating
# 1    2022-03-02 22:12:17  ...                   Monty B. VIII
# 2    2022-03-02 22:07:33  ...                       Azor_Ahai
# 3    2022-03-02 22:06:35  ...                        Motive81
# 4    2022-03-02 22:06:04  ...                       the HI GI
# ...                  ...  ...                             ...
# 3866 2022-02-22 20:06:08  ...  Trade With Zero Emotion | Vini
# 3867 2022-02-22 20:04:33  ...                      DarthTrada
# 3868 2022-02-22 20:04:27  ...                         Felix S
# 3869 2022-02-22 20:02:45  ...  Trade With Zero Emotion | Vini
# 3870 2022-02-22 20:00:14  ...                           Dana🌸
#
# [3871 rows x 4 columns]

# %%
tweets_dataf.to_csv("TSLA_tweets.csv")

# %%
# import tweepy,json
# access_token="1493304130957287424-QgO1HCfvKwampf10kxjlfjXiV0TA2E"
# access_token_secret="R5x7ynRPI4uqHf5SH0U0VXZsfseU1CpJc4rRTF1hvqFxy"
# consumer_key= "3xGEYTZh3QqQGVOnU287HgxzV" # API KEY
# consumer_secret="9fLftqyNPwT7yps3sPu2JY5fF2D87XCy5UX1heSrymJpLLoyVX" # API SECRET

# %%
# # Twitter authentication
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)   
# auth.set_access_token(access_token, access_token_secret) 
  
# # Creating an API object 
# api = tweepy.API(auth)

# %%
# begin = time.time()
# mention_tweets = tweepy.Cursor(api.search_tweets, q="$GOOGL", since="2022-2-19", 
#                                tweet_mode='extended').items()
